# %%
import pandas as pd
from pathlib import Path

in_path = Path("Claude_eval_with_gt.csv")
df = pd.read_csv(in_path)

# Robust match: treat NaN as empty; case-insensitive contains "hourly"
mask_multi = df["query_id"].astype(str).str.contains("hourly", case=False, na=False)

df_multi_step = df.loc[mask_multi].copy()
df_point = df.loc[~mask_multi].copy()

out_multi = in_path.with_name("Claude_multi_step.csv")
out_point = in_path.with_name("Claude_point_forecast.csv")

df_multi_step.to_csv(out_multi, index=False)
df_point.to_csv(out_point, index=False)

{
    "input_rows": len(df),
    "multi_step_rows": len(df_multi_step),
    "point_forecast_rows": len(df_point),
    "multi_step_file": str(out_multi),
    "point_forecast_file": str(out_point),
    "sample_multi_query_ids": df_multi_step["query_id"].head(5).tolist() if "query_id" in df_multi_step.columns else None,
    "sample_point_query_ids": df_point["query_id"].head(5).tolist() if "query_id" in df_point.columns else None,
}
# Out:
# {'input_rows': 90,
#  'multi_step_rows': 45,
#  'point_forecast_rows': 45,
#  'multi_step_file': 'Claude_multi_step.csv',
#  'point_forecast_file': 'Claude_point_forecast.csv',
#  'sample_multi_query_ids': ['hourly_NSW1_004',
#   'hourly_NSW1_003',
#   'hourly_QLD1_008',
#   'hourly_VIC1_006',
#   'hourly_QLD1_009'],
#  'sample_point_query_ids': ['short_term_NSW1_001',
#   'short_term_VIC1_005',
#   'short_term_NSW1_002',
#   'long_term_QLD1_007',
#   'mid_term_TAS1_011']}

# %%
import pandas as pd
from pathlib import Path

in_path = Path("Gemini_eval_with_gt.csv")
df = pd.read_csv(in_path)

# Robust match: treat NaN as empty; case-insensitive contains "hourly"
mask_multi = df["query_id"].astype(str).str.contains("hourly", case=False, na=False)

df_multi_step = df.loc[mask_multi].copy()
df_point = df.loc[~mask_multi].copy()

out_multi = in_path.with_name("Gemini_multi_step.csv")
out_point = in_path.with_name("Gemini_point_forecast.csv")

df_multi_step.to_csv(out_multi, index=False)
df_point.to_csv(out_point, index=False)

{
    "input_rows": len(df),
    "multi_step_rows": len(df_multi_step),
    "point_forecast_rows": len(df_point),
    "multi_step_file": str(out_multi),
    "point_forecast_file": str(out_point),
    "sample_multi_query_ids": df_multi_step["query_id"].head(5).tolist() if "query_id" in df_multi_step.columns else None,
    "sample_point_query_ids": df_point["query_id"].head(5).tolist() if "query_id" in df_point.columns else None,
}
# Out:
# {'input_rows': 225,
#  'multi_step_rows': 117,
#  'point_forecast_rows': 108,
#  'multi_step_file': 'Gemini_multi_step.csv',
#  'point_forecast_file': 'Gemini_point_forecast.csv',
#  'sample_multi_query_ids': ['hourly_NSW1_001',
#   'hourly_VIC1_005',
#   'hourly_NSW1_002',
#   'hourly_NSW1_001',
#   'hourly_VIC1_005'],
#  'sample_point_query_ids': ['short_term_NSW1_001',
#   'short_term_VIC1_005',
#   'short_term_NSW1_002',
#   'long_term_QLD1_007',
#   'mid_term_TAS1_011']}

# %%
import pandas as pd
from pathlib import Path

in_path = Path("OpenAI_eval_with_gt.csv")
df = pd.read_csv(in_path)

# Robust match: treat NaN as empty; case-insensitive contains "hourly"
mask_multi = df["query_id"].astype(str).str.contains("hourly", case=False, na=False)

df_multi_step = df.loc[mask_multi].copy()
df_point = df.loc[~mask_multi].copy()

out_multi = in_path.with_name("OpenAI_multi_step.csv")
out_point = in_path.with_name("OpenAI_point_forecast.csv")

df_multi_step.to_csv(out_multi, index=False)
df_point.to_csv(out_point, index=False)

{
    "input_rows": len(df),
    "multi_step_rows": len(df_multi_step),
    "point_forecast_rows": len(df_point),
    "multi_step_file": str(out_multi),
    "point_forecast_file": str(out_point),
    "sample_multi_query_ids": df_multi_step["query_id"].head(5).tolist() if "query_id" in df_multi_step.columns else None,
    "sample_point_query_ids": df_point["query_id"].head(5).tolist() if "query_id" in df_point.columns else None,
}
# Out:
# {'input_rows': 225,
#  'multi_step_rows': 112,
#  'point_forecast_rows': 113,
#  'multi_step_file': 'OpenAI_multi_step.csv',
#  'point_forecast_file': 'OpenAI_point_forecast.csv',
#  'sample_multi_query_ids': ['hourly_NSW1_001',
#   'hourly_VIC1_005',
#   'hourly_NSW1_002',
#   'hourly_NSW1_001',
#   'hourly_VIC1_005'],
#  'sample_point_query_ids': ['short_term_NSW1_001',
#   'short_term_VIC1_005',
#   'short_term_NSW1_002',
#   'long_term_QLD1_007',
#   'mid_term_TAS1_011']}

# %%
import pandas as pd
from pathlib import Path

in_path = Path("DeepSeek_eval_with_gt.csv")
df = pd.read_csv(in_path)

# Robust match: treat NaN as empty; case-insensitive contains "hourly"
mask_multi = df["query_id"].astype(str).str.contains("hourly", case=False, na=False)

df_multi_step = df.loc[mask_multi].copy()
df_point = df.loc[~mask_multi].copy()

out_multi = in_path.with_name("DeepSeek_multi_step.csv")
out_point = in_path.with_name("DeepSeek_point_forecast.csv")

df_multi_step.to_csv(out_multi, index=False)
df_point.to_csv(out_point, index=False)

{
    "input_rows": len(df),
    "multi_step_rows": len(df_multi_step),
    "point_forecast_rows": len(df_point),
    "multi_step_file": str(out_multi),
    "point_forecast_file": str(out_point),
    "sample_multi_query_ids": df_multi_step["query_id"].head(5).tolist() if "query_id" in df_multi_step.columns else None,
    "sample_point_query_ids": df_point["query_id"].head(5).tolist() if "query_id" in df_point.columns else None,
}
# Out:
# {'input_rows': 225,
#  'multi_step_rows': 117,
#  'point_forecast_rows': 108,
#  'multi_step_file': 'DeepSeek_multi_step.csv',
#  'point_forecast_file': 'DeepSeek_point_forecast.csv',
#  'sample_multi_query_ids': ['hourly_NSW1_001',
#   'hourly_VIC1_005',
#   'hourly_NSW1_002',
#   'hourly_NSW1_001',
#   'hourly_VIC1_005'],
#  'sample_point_query_ids': ['short_term_NSW1_001',
#   'short_term_VIC1_005',
#   'short_term_NSW1_002',
#   'long_term_QLD1_007',
#   'mid_term_TAS1_011']}
